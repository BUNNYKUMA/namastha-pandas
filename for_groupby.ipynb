# %% [markdown]
# <a href="https://colab.research.google.com/github/BUNNYKUMA/namastha-pandas/blob/main/for_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
# import    
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/COVID-19_Vaccinations_in_the_United_States_County.csv')

# %%
# data.groupby('')
data.head()
# Out:
#          Date  ... Series_Complete_65PlusPop_Pct_UR_Equity
# 0  11/18/2021  ...                                     8.0
# 1  11/18/2021  ...                                     7.0
# 2  11/18/2021  ...                                     8.0
# 3  11/18/2021  ...                                     NaN
# 4  11/18/2021  ...                                     8.0
#
# [5 rows x 32 columns]

# %%
g = data.groupby('Recip_County')
g

# %%
for Recip_County, data in g:
    print(Recip_County)
    print(data)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1112911  12/15/2020  ...                                     NaN
# 1118731  12/14/2020  ...                                     NaN
# 1119930  12/13/2020  ...                                     NaN
#
# [343 rows x 32 columns]
# Somerset County
#                Date  ... Series_Complete_65PlusPop_Pct_UR_Equity
# 501      11/18/2021  ...                                     8.0
# 566      11/18/2021  ...                                     4.0
# 2686     11/18/2021  ...                                     8.0
# 2900     11/18/2021  ...                                     4.0
# 3352     11/17/2021  ...                                     8.0
# ...             ...  ...                                     ...
# 1118043  12/14/2020  ...                                     NaN
# 1119407  12/13/2020  ...                                     NaN
# 1120277  12/13/2020  ...                                     NaN
# ...

# %%
g.get_group('Lawrence County').tail()
# Out:
#                Date  ... Series_Complete_65PlusPop_Pct_UR_Equity
# 1121629  12/13/2020  ...                                     NaN
# 1121665  12/13/2020  ...                                     NaN
# 1121735  12/13/2020  ...                                     NaN
# 1121886  12/13/2020  ...                                     NaN
# 1122082  12/13/2020  ...                                     NaN
#
# [5 rows x 32 columns]

# %%
df = g.get_group('Lawrence County')

# %%
import seaborn as sns
df1 = df.dropna()
sns.histplot(df1.Series_Complete_Pop_Pct)
# df

# %%
max = df1.Series_Complete_Pop_Pct.max()
min = df1.Series_Complete_Pop_Pct.min()
range = max - min
range
# Out:
# 50.699999999999996

# %%
3105-3763
# Out:
# -658

# %%
g.Recip_County.max()
# Out:
# Recip_County
# Abbeville County                      Abbeville County
# Acadia Parish                            Acadia Parish
# Accomack County                        Accomack County
# Ada County                                  Ada County
# Adair County                              Adair County
#                                        ...
# Yukon-Koyukuk Census Area    Yukon-Koyukuk Census Area
# Yuma County                                Yuma County
# Zapata County                            Zapata County
# Zavala County                            Zavala County
# Ziebach County                          Ziebach County
# Name: Recip_County, Length: 1960, dtype: object

# %%
g.median()
# g.min()
# Out:
#                            MMWR_week  ...  Series_Complete_65PlusPop_Pct_UR_Equity
# Recip_County                          ...
# Abbeville County                25.0  ...                                      7.0
# Acadia Parish                   25.0  ...                                      4.0
# Accomack County                 25.0  ...                                      8.0
# Ada County                      25.0  ...                                      4.0
# Adair County                    25.0  ...                                      7.0
# ...                              ...  ...                                      ...
# Yukon-Koyukuk Census Area       25.0  ...                                      8.0
# Yuma County                     25.0  ...                                      4.0
# Zapata County                   25.0  ...                                      8.0
# Zavala County                   25.0  ...                                      8.0
# ...

# %%
a = g.head(1960)

# %%
a.describe()
# Out:
#            MMWR_week  ...  Series_Complete_65PlusPop_Pct_UR_Equity
# count  976361.000000  ...                            800387.000000
# mean       26.123357  ...                                 5.245360
# std        14.222024  ...                                 2.243166
# min         1.000000  ...                                 1.000000
# 25%        14.000000  ...                                 4.000000
# 50%        27.000000  ...                                 5.000000
# 75%        38.000000  ...                                 7.000000
# max        53.000000  ...                                 8.000000
#
# [8 rows x 26 columns]
