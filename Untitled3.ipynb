# %%
from autoscraper import AutoScraper

# %%
url = "https://www.flipkart.com/search?q=iphone"

wanted_list = ("₹49,900","APPLE iPhone 11 (Black, 64 GB)","77,205","5,844")

# %%
scraper = AutoScraper()
result = scraper.build(url,wanted_list)
print(result)
# Out:
# ['₹59,99919% off', '₹62,99911% off', '₹44,99918% off', '₹49,900', '₹47,900', '₹56,999₹65,90013% off', '₹62,999₹70,90011% off', '₹29,999₹39,90024% off', '₹49,999₹64,90022% off', '₹44,999₹59,90024% off', '₹34,999₹44,90022% off', '₹59,999₹74,90019% off', '₹44,999₹54,90018% off', 'APPLE iPhone 12 Mini (White, 256 GB)', 'APPLE iPhone 12 (Blue, 128 GB)', 'APPLE iPhone SE (Red, 256 GB)', 'APPLE iPhone 11 (Black, 64 GB)', 'APPLE iPhone XR (Black, 64 GB)', 'APPLE iPhone 12 (Black, 64 GB)', 'APPLE iPhone SE (Black, 64 GB)', 'APPLE iPhone 12 Mini (Purple, 128 GB)', 'APPLE iPhone SE (White, 64 GB)', 'APPLE iPhone SE (Red, 64 GB)', 'APPLE iPhone 12 Mini (White, 64 GB)', 'APPLE iPhone 12 Mini (Blue, 128 GB)', 'APPLE iPhone 12 Mini (Red, 128 GB)', 'APPLE iPhone 12 Mini (Black, 64 GB)', 'APPLE iPhone 12 (Red, 128 GB)', 'APPLE iPhone 12 Mini (Blue, 64 GB)', 'APPLE iPhone 12 (Red, 64 GB)', 'APPLE iPhone 12 Mini (Purple, 64 GB)', 'APPLE iPhone 12 Mini (Black, 128 GB)', 'APPLE iPhone SE (White, 128 GB)'
# ...

# %%
scraper.get_result_similar(url,grouped=True)
# Out:
# {'rule_3agx': ['₹59,99919% off',
#   '₹62,99911% off',
#   '₹44,99918% off',
#   '₹49,900',
#   '₹47,900'],
#  'rule_4ix4': ['APPLE iPhone 12 Mini (White, 256 GB)',
#   'APPLE iPhone 12 (Blue, 128 GB)',
#   'APPLE iPhone SE (Red, 256 GB)',
#   'APPLE iPhone 11 (Black, 64 GB)',
#   'APPLE iPhone XR (Black, 64 GB)'],
#  'rule_d4nw': ['₹62,999₹70,90011% off',
#   '₹56,999₹65,90013% off',
#   '₹29,999₹39,90024% off',
#   '₹49,999₹64,90022% off',
#   '₹29,999₹39,90024% off',
#   '₹29,999₹39,90024% off',
#   '₹44,999₹59,90024% off',
#   '₹49,999₹64,90022% off',
#   '₹49,999₹64,90022% off',
#   '₹44,999₹59,90024% off',
#   '₹62,999₹70,90011% off',
#   '₹44,999₹59,90024% off',
#   '₹56,999₹65,90013% off',
#   '₹44,999₹59,90024% off',
#   '₹49,999₹64,90022% off',
#   '₹34,999₹44,90022% off',
#   '₹34,999₹44,90022% off',
#   '₹34,999₹44,90022% off',
#   '₹44,999₹59,90024% off',
#   '₹47,900',
#   '₹47,900',
#   '₹59,999₹74,90019% off',
#   '₹44,999₹54,90018% off',
#   '₹49,900'],
# ...

# %%
scraper.get_result_similar(url,grouped=True)
# Out:
# {'rule_3agx': ['₹59,99919% off',
#   '₹62,99911% off',
#   '₹44,99918% off',
#   '₹49,900',
#   '₹47,900'],
#  'rule_4ix4': ['APPLE iPhone 12 Mini (White, 256 GB)',
#   'APPLE iPhone 12 (Blue, 128 GB)',
#   'APPLE iPhone SE (Red, 256 GB)',
#   'APPLE iPhone 11 (Black, 64 GB)',
#   'APPLE iPhone XR (Black, 64 GB)'],
#  'rule_d4nw': ['₹62,999₹70,90011% off',
#   '₹56,999₹65,90013% off',
#   '₹29,999₹39,90024% off',
#   '₹49,999₹64,90022% off',
#   '₹29,999₹39,90024% off',
#   '₹29,999₹39,90024% off',
#   '₹44,999₹59,90024% off',
#   '₹49,999₹64,90022% off',
#   '₹49,999₹64,90022% off',
#   '₹44,999₹59,90024% off',
#   '₹62,999₹70,90011% off',
#   '₹44,999₹59,90024% off',
#   '₹56,999₹65,90013% off',
#   '₹44,999₹59,90024% off',
#   '₹49,999₹64,90022% off',
#   '₹34,999₹44,90022% off',
#   '₹34,999₹44,90022% off',
#   '₹34,999₹44,90022% off',
#   '₹44,999₹59,90024% off',
#   '₹47,900',
#   '₹47,900',
#   '₹59,999₹74,90019% off',
#   '₹44,999₹54,90018% off',
#   '₹49,900'],
# ...

# %%
# scraper.set_rule_aliases({'rule_ci84':"Title"})
# scraper.keep_rules(['rule_ci84'])
# scraper.save('amazon seaarch')
